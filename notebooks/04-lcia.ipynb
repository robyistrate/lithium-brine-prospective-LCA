# %% [markdown]
# # Life Cycle Impact Assessment (LCIA)
#
# This notebook performs the impact assessment calculations including sensitivity analysis using *presamples* and export the results.

# %%
import bw2data as bd
import bw2calc as bc
import presamples as ps
import pandas as pd
import numpy as np
from pathlib import Path
import yaml
import pickle
import datetime
import copy

from utils import (
    recursive_calculation_cumulative_flows, 
    multi_lca,
    get_sensitivity_analysis_data,
    run_scenario_lca_matrices)
# Out:
# c:\Users\istrateir\AppData\Local\miniconda3\envs\plca\Lib\site-packages\bw2calc\__init__.py:57: UserWarning: No fast sparse solver found
#   warnings.warn("No fast sparse solver found")
# 19:01:30+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.

# %% [markdown]
# ## 1. Basic set-up

# %%
SCENARIO_DATA_PATH = Path("../scenario_data")
RESULTS_PATH = Path("../results")

# Open BW project
BW_PROJECT = 'plca_lithium'
bd.projects.set_current(BW_PROJECT)
print(bd.databases)

# Impact assessment methods
LCIA_METHODS = {
    'Climate change': ('IPCC 2021', "climate change", 'GWP 100a, incl. H and bio CO2'),
    'Water scarcity': ('AWARE regionalized', 'Annual', 'All')
}
impact_methods_obj = {"impact_categories": list(LCIA_METHODS.values())}

# Databases
BACKGROUND_DB = [
    "ei_cutoff_3.10_remind_SSP2-NDC_2025_STEPS 2025-11-14",
	"ei_cutoff_3.10_remind_SSP2-NDC_2035_STEPS 2025-11-14"
]
BIO_DBs = ["ecoinvent-3.10.1-biosphere", "biosphere-3.10.1-water regionalized"]

# Import lithium scenario results
lithium_scenario_data = pd.read_csv(SCENARIO_DATA_PATH / "external" / "lithium_scenario_data_with_LCIs_07-11-2025.csv", index_col=0)
lithium_production_by_country = pd.read_csv(RESULTS_PATH / "lithium_production_by_country_07-11-2025.csv", index_col=0)
lithium_production_total = pd.read_csv(RESULTS_PATH / "lithium_production_total_07-11-2025.csv", index_col=0)

# Import map of lithium project names to LCI datasets
map_lithium_projects_to_lci = pd.read_excel(SCENARIO_DATA_PATH / "lithium_projects_list.xlsx")

# Import annonymized IDs for projects
with open(SCENARIO_DATA_PATH / "external" / "anonymized_projects_id.yaml", "r") as yaml_file:
    anonymized_projects_id = yaml.safe_load(yaml_file)
# Out:
# Databases dictionary with 22 objects, including:
# 	biosphere-3.10-water regionalized
# 	biosphere-3.10.1-water regionalized
# 	ecoinvent-3.10-biosphere
# 	ecoinvent-3.10-cutoff
# 	ecoinvent-3.10.1-biosphere
# 	ecoinvent-3.10.1-cutoff
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ei_cutoff_3.10_remind_SSP2-NDC_2025_STEPS 2025-11-14
# 	ei_cutoff_3.10_remind_SSP2-NDC_2035_STEPS 2025-11-14
# Use `list(this object)` to get the complete list.

# %% [markdown]
# ## 1. Project-level contribution analysis
#
# To reduce computational time, the following strategy applies:
#
# 1. Cumulative LCI exchanges (technosphere and biosphere) for each project is calculated.
# 2. A list of all required background (technosphere) datasets is obtained.
# 3. Calculate impacts per unit of each background dataset.
# 4. Combine cumulative LCI exchanges with impacts per unit.

# %%
# Use the "Very Ambitious" scenario, which contains all the projects
# Note that the impacts of projects do not change across supply scenarios
# Only their market shares change
process_contribution_dbs = [ 
    'lithium_baseline_S&P-Baseline_remind SSP2-NDC 2025',
    'lithium_baseline_S&P-Very Ambitious_remind SSP2-NDC 2035',
    "lithium_optimized_S&P-Very Ambitious_remind SSP2-NDC 2035",
    'lithium_optimized+elec-heat_S&P-Very Ambitious_remind SSP2-NDC 2035'
]

# %%
# 1. Get cumulative list of exchanges for each project in each database
project_cumulative_flows = {}

for db in process_contribution_dbs:
    project_cumulative_flows[db] = {}

    for index, proj in map_lithium_projects_to_lci.iterrows():

        # Identify the project name and the activity for the correspoding database
        if "df_rotary_dryer_" in proj["LCI dataset"]:
            activity = [a for a in bd.Database(db) if a["name"]==proj["LCI dataset"]][0]
            project_lci_name = proj["LCI dataset"].split("df_rotary_dryer_")[1]
        else:
            raise ValueError(f"Unexpected LCI dataset format: {proj['LCI dataset']}")

        # Get foreground processes for the project
        foreground_processes = [a for a in bd.Database(db) if project_lci_name in a["name"]]
        if not foreground_processes:
            raise KeyError(f"Project-related datasets not found for project: {project_lci_name}")
                
        # Calculate project cumulative LCI flows
        project_cumulative_flows[db][project_lci_name] = recursive_calculation_cumulative_flows(activity, foreground_processes, amount=1)

# %%
# 2. Perform LCIA for background datasets
# Create a dictionary of unique background datasets
unique_background_ds = {}
for db, proj in project_cumulative_flows.items():
    unique_background_ds[db] = set()
    for p in proj:
        for f in proj[p]:
            if f["database"] not in BIO_DBs:
                if "lithium" not in f["database"]:
                    unique_background_ds[db].add(f)

# Perform LCIA of background datasets
lcia_background_datasets = {}
for db in unique_background_ds:
    list_datasets = list(unique_background_ds[db])
    print("Database:", db)
    print("Performing LCIA of background datasets:", len(list_datasets), "datasets")

    lcia_background_datasets[db] = multi_lca(list_datasets, impact_methods_obj)
# Out:
# Database: lithium_baseline_S&P-Baseline_remind SSP2-NDC 2025
# Performing LCIA of background datasets: 27 datasets
# Database: lithium_baseline_S&P-Very Ambitious_remind SSP2-NDC 2035
# Performing LCIA of background datasets: 27 datasets
# Database: lithium_optimized_S&P-Very Ambitious_remind SSP2-NDC 2035
# Performing LCIA of background datasets: 27 datasets
# Database: lithium_optimized+elec-heat_S&P-Very Ambitious_remind SSP2-NDC 2035
# Performing LCIA of background datasets: 27 datasets

# %%
# Perform LCIA of heat pumps datasets
list_hp_datasets = [ds for ds in bd.Database('lithium_optimized+elec-heat_S&P-Very Ambitious_remind SSP2-NDC 2035') if 'heat' in ds["name"]]
lca_heat_pumps = multi_lca(list_hp_datasets, impact_methods_obj)

# Add LCIA of heat pumps to the background datasets dict
lcia_background_datasets_expanded = copy.deepcopy(lcia_background_datasets)
for db in lcia_background_datasets_expanded:
    if db == 'lithium_optimized+elec-heat_S&P-Very Ambitious_remind SSP2-NDC 2035':
        lcia_background_datasets_expanded[db].update(lca_heat_pumps)

# %%
# Export impacts of background datasets to a pickle file
with open(RESULTS_PATH / "raw" / f"lca_background_datasets_{datetime.datetime.today().strftime('%d-%m-%Y')}.pkl", 'wb') as f:
    pickle.dump(lcia_background_datasets_expanded, f)

# Load LCA results of background datasets
#with open(RESULTS_PATH / f"raw/lca_background_datasets_13-10-2025.pkl", 'rb') as f:
#    lcia_background_datasets_expanded = pickle.load(f)

# %%
# 4. Calculate total impact and impact contribution for each project by combining cumulative LCI flows
# with impacts per unit for background datasets and characterization factors for elementary flows
projects_process_contribution = []

# List of products for breakdown analysis
with open("breakdown_lists.yaml", "r") as yaml_file:
    breakdown_lists = yaml.safe_load(yaml_file)

for db in project_cumulative_flows:
    for proj in project_cumulative_flows[db]:
        # Group impacts into the defined categories and add contribution from biosphere flows
        for impact_name, impact_method in LCIA_METHODS.items():
            process_contribution = {category: 0 for category in list(breakdown_lists.keys()) + ["Other"]}
            
            # Get method's characterization factors
            method_CFs = {ef[0]: ef[1] for ef in bd.Method(impact_method).load()}

            for exc in project_cumulative_flows[db][proj]:
                if exc["type"]=="processwithreferenceproduct":
                    back_key = (impact_method, (exc["name"] + "|" + exc["reference product"] + "|" + exc["location"]))
                    # Calculate impact of cumulative technosphere exchange
                    if back_key not in lcia_background_datasets_expanded[db]:
                        raise KeyError
                    exc_impact = project_cumulative_flows[db][proj][exc] * lcia_background_datasets_expanded[db][back_key]

                    contribution_added = False
                    for category, category_items in breakdown_lists.items():
                        if exc["reference product"] in category_items:
                            process_contribution[category] += exc_impact
                            contribution_added = True
                    if not contribution_added:
                        process_contribution["Other"] += exc_impact

                # Add biosphere impacts:
                elif exc["type"]=="emission":
                    if exc.id in method_CFs:
                        process_contribution["Direct emissions"] += project_cumulative_flows[db][proj][exc] * method_CFs[exc.id]

            lci_dataset_name = "df_rotary_dryer_"+proj
            project_technology = map_lithium_projects_to_lci[map_lithium_projects_to_lci["LCI dataset"]==lci_dataset_name]["Technology"].values[0]
            project_status = map_lithium_projects_to_lci[map_lithium_projects_to_lci["LCI dataset"]==lci_dataset_name]["Status"].values[0]
            projects_process_contribution.append((proj, lci_dataset_name, project_technology, project_status, impact_name, db) + tuple(process_contribution.values()))

projects_process_contribution_df = pd.DataFrame(projects_process_contribution,
                                                columns=["Project name", "LCI dataset", "Technology", "Status", "Impact", "Scenario"] + [category for category in list(breakdown_lists.keys())] + ["Other"])


# Calculate total impact from summming contributions
projects_process_contribution_df["Total_contrib"] = projects_process_contribution_df[["Electricity", "Heat", "Reagents", "Direct emissions", "Other"]].sum(axis=1)

# Calculate total impacts for projects
proj_total_impact = []
for db in project_cumulative_flows:
    projects_ds = [ds for ds in bd.Database(db) if "df_rotary_dryer_" in ds["name"]]
    proj_impact_total = multi_lca(projects_ds, impact_methods_obj)
    for i in proj_impact_total:
        impact_value = proj_impact_total[i]
        proj_name = i[1].split("|")[0]
        impact_cat = [k for k,v in LCIA_METHODS.items() if v==i[0]][0]
        proj_total_impact.append((proj_name, impact_cat, db, impact_value))
    proj_total_impact_df = pd.DataFrame(proj_total_impact, columns=["LCI dataset", "Impact", "Scenario", "Total"])

projects_process_contribution_df = pd.merge(projects_process_contribution_df, proj_total_impact_df, on=['LCI dataset', 'Impact', 'Scenario'], how="inner")

# %%
# Export project-specific process contribution
projects_process_contribution_df.to_csv(RESULTS_PATH / f"impacts_by_project_breakdown_{datetime.datetime.today().strftime('%d-%m-%Y')}.csv", index=0)

# Import results for further analysis
#projects_process_contribution_df = pd.read_csv(RESULTS_PATH / "impacts_by_project_breakdown_13-10-2025.csv")

# %% [markdown]
# ## 2. Market-level contribution analysis

# %%
MARKET_SCENARIOS = [
    "S&P-Baseline",
    "S&P-Ambitious",
    "S&P-Very Ambitious"
]

# %% [markdown]
# **Market-level impact intensity by country**

# %%
# Calculate impacts by country, intensity (kg CO2-eq/kg) and total (Mt CO2-eq/year)
impacts_by_country = []

for market_sc in MARKET_SCENARIOS:
    li_sc_dbs = [db for db in bd.databases if market_sc in db]
    for li_db in li_sc_dbs:
        year = "2025" if "2025" in li_db else "2035"

        # Calculate impact intensity by country
        market_actv = [a for a in bd.Database(li_db) if a["name"] == 'market for lithium carbonate, from brine, S&P forecasts']
        lca_markets = multi_lca(market_actv, impact_methods_obj)

        # Calculate contribution to global intensity by country and total country impact
        glo_market = [a for a in bd.Database(li_db) 
                       if a["name"] == 'market for lithium carbonate, from brine, S&P forecasts'
                       and a["location"]=="World"][0]
        glo_production = lithium_production_total.loc[market_sc][year] * 1e6
        print(li_db)
        # Add global impacts
        for impact in LCIA_METHODS:
            glo_key = (LCIA_METHODS[impact], (glo_market["name"] + "|" + glo_market["reference product"] + "|" + glo_market["location"]))
            glo_intensity = lca_markets[glo_key]
            glo_total = glo_production * glo_intensity
            impacts_by_country.append((market_sc, li_db, impact, "World", glo_intensity, glo_total, glo_intensity))

        for country_ds in glo_market.technosphere():
            country_production = glo_production * country_ds["amount"]
            for impact in LCIA_METHODS:
                country_key = (LCIA_METHODS[impact], (country_ds["name"] + "|" + country_ds["product"] + "|" + country_ds["location"]))
                country_intensity = lca_markets[country_key]
                country_contribution_glo_intensity = country_intensity * country_ds["amount"]
                country_total = country_production * country_intensity
                impacts_by_country.append((market_sc, li_db, impact, country_ds["location"], country_intensity, country_total, country_contribution_glo_intensity))

impacts_by_country_df = pd.DataFrame(impacts_by_country, columns=["Market scenario", "Li scenario", "Impact", "Country", 'Intensity', "Total", "GLO intensity"])
# Convert total impact to Mt CO2eq or billion m3
impacts_by_country_df["Total"] /= 1e9
# Out:
# lithium_baseline_S&P-Baseline_remind SSP2-NDC 2025
# lithium_baseline_S&P-Baseline_remind SSP2-NDC 2035
# lithium_optimized_S&P-Baseline_remind SSP2-NDC 2035
# lithium_optimized+elec-heat_S&P-Baseline_remind SSP2-NDC 2035
# lithium_baseline_S&P-Ambitious_remind SSP2-NDC 2035
# lithium_optimized_S&P-Ambitious_remind SSP2-NDC 2035
# lithium_optimized+elec-heat_S&P-Ambitious_remind SSP2-NDC 2035
# lithium_baseline_S&P-Very Ambitious_remind SSP2-NDC 2035
# lithium_optimized_S&P-Very Ambitious_remind SSP2-NDC 2035
# lithium_optimized+elec-heat_S&P-Very Ambitious_remind SSP2-NDC 2035

# %%
# Export LCA results by country
impacts_by_country_df.to_csv(RESULTS_PATH / f"impacts_by_country_{datetime.datetime.today().strftime('%d-%m-%Y')}.csv", index=0)

# Import results for further analysis
#impacts_by_country_df = pd.read_csv(RESULTS_PATH / "annual_impacts_by_country_25-02-2025.csv")

# %% [markdown]
# **Market-level impact intensity by technology and impact source**

# %%
# Calculate global impacts contribution by technology and impact source based on project-specific data and market shares
glo_technology_contribution = {}
glo_process_contribution = []

for market_sc in MARKET_SCENARIOS:
    li_sc_dbs = [db for db in bd.databases if market_sc in db]
    for li_db in li_sc_dbs:
        year = "2025" if "2025" in li_db else "2035"
        glo_market = [a for a in bd.Database(li_db) 
                      if a["name"]=="market for lithium carbonate, from brine, S&P forecasts" 
                      and a["location"]=="World"][0]

        # Project-level contribution analysis was performed only for the Very Ambitious scenario
        if year=="2025":
            contrib_sc = 'lithium_baseline_S&P-Baseline_remind SSP2-NDC 2025'
        elif year=="2035":
            if "lithium_baseline_" in li_db:
                contrib_sc = 'lithium_baseline_S&P-Very Ambitious_remind SSP2-NDC 2035'
            elif "lithium_optimized_" in li_db:
                contrib_sc = 'lithium_optimized_S&P-Very Ambitious_remind SSP2-NDC 2035'
            elif "lithium_optimized+elec" in li_db:
                contrib_sc = 'lithium_optimized+elec-heat_S&P-Very Ambitious_remind SSP2-NDC 2035'
        
        for impact in LCIA_METHODS:
            technology_impact_contribution = {}
            electricity_contribution = 0
            heat_contribution = 0
            reagent_contribution = 0
            foreground_contribution = 0
            other_contribution = 0
            
            # Iterate over country markets
            for country_ds in glo_market.technosphere():
                print(country_ds["location"])
                country_production = country_ds["amount"]
                
                # Iterate over projects within each ountry
                for project_ds in country_ds.input.technosphere():
                    project_production = country_production * project_ds["amount"]
                    print(project_ds["name"],project_production )
                    # Get dataframe with project impacts breakdown (only available for Very Ambitious)
                    project_impacts_df = projects_process_contribution_df[(projects_process_contribution_df["LCI dataset"]==project_ds["name"]) &
                                                                            (projects_process_contribution_df["Impact"]==impact) &
                                                                            (projects_process_contribution_df["Scenario"]==contrib_sc)]
                    
                    # Calculate technology contribution
                    project_technology = map_lithium_projects_to_lci[map_lithium_projects_to_lci["LCI dataset"] == project_ds["name"]]["Technology"].values[0]
                    if project_technology not in technology_impact_contribution:
                        technology_impact_contribution[project_technology] = project_impacts_df["Total"].values[0] * project_production
                    else:
                        technology_impact_contribution[project_technology] += project_impacts_df["Total"].values[0] * project_production

                    # Caculate background process contribution
                    electricity_contribution += project_impacts_df["Electricity"].values[0] * project_production
                    heat_contribution += project_impacts_df["Heat"].values[0] * project_production
                    reagent_contribution += project_impacts_df["Reagents"].values[0] * project_production      
                    foreground_contribution += project_impacts_df["Direct emissions"].values[0] * project_production       
                    other_contribution += project_impacts_df["Other"].values[0] * project_production                                 

            glo_technology_contribution[(market_sc, li_db, impact)] = technology_impact_contribution
            glo_process_contribution.append((market_sc, li_db, impact, electricity_contribution, heat_contribution, reagent_contribution, foreground_contribution, other_contribution))

# Covert to dataframes
glo_technology_contribution_df = []
for (market_sc, li_db, impact), contributions in glo_technology_contribution.items():
    for technology, value in contributions.items():
        glo_technology_contribution_df.append({
            'Market scenario': market_sc,
            'Li scenario': li_db,
            'Impact': impact,
            'Technology': technology,
            'Total': value
        })
glo_technology_contribution_df = pd.DataFrame(glo_technology_contribution_df)

glo_process_contribution_df = pd.DataFrame(glo_process_contribution, columns=["Market scenario", "Li scenario", "Impact",
                                    "Electricity", "Heat", "Reagents", "Direct emissions", "Other"])
glo_process_contribution_df["Total"] = glo_process_contribution_df[["Electricity", "Heat", "Reagents", "Direct emissions", "Other"]].sum(axis=1)
# Out:
# AR
# df_rotary_dryer_Salar de Cauchari-Olaroz 0.08382388182529944
# df_rotary_dryer_Salar de Centenario 0.03352871040602969
# df_rotary_dryer_Salar de Olaroz 0.0775696254563817
# df_rotary_dryer_Fenix 0.06843883231980687
# df_rotary_dryer_Sal de los Angeles 0.0052645255630620665
# CL
# df_rotary_dryer_Salar de Atacama 0.5740880894110175
# CN
# df_rotary_dryer_Chaerhan 0.09741056939845004
# df_rotary_dryer_East Taijinar 0.03352871040602969
# df_rotary_dryer_Zhabuye 0.016681386280140986
# US
# df_rotary_dryer_Silver Peak 0.009665668933781955
# AR
# df_rotary_dryer_Salar de Cauchari-Olaroz 0.08382388182529944
# df_rotary_dryer_Salar de Centenario 0.03352871040602969
# df_rotary_dryer_Salar de Olaroz 0.0775696254563817
# df_rotary_dryer_Fenix 0.06843883231980687
# df_rotary_dryer_Sal de los Angeles 0.0052645255630620665
# CL
# df_rotary_dryer_Salar de Atacama 0.5740880894110175
# CN
# df_rotary_dryer_Chaerhan 0.09741056939845004
# df_rotary_dryer_East Taijinar 0.03352871040602969
# df_rotary_dryer_Zhabuye 0.016681386280140986
# US
# df_rotary_dryer_Silver Peak 0.009665668933781955
# AR
# df_rotary_dryer_Salar de Cauchari-Olaroz 0.08721864600074083
# df_rotary_dryer_Salar de Centenario 0.03483145739694503
# df_rotary_dryer_Salar de Olaroz 0.05787937033871857
# df_rotary_dryer_Fenix 0.16545817279226252
# df_rotary_dryer_Sal de los Angeles 0.04375078386821097
# CL
# df_rotary_dryer_Salar de Atacama 0.45156204882004136
# CN
# df_rotary_dryer_Chaerhan 0.11112990774418041
# df_rotary_dryer_East Taijinar 0.02321999935832184
# df_rotary_dryer_Zhabuye 0.013516075496352644
# US
# df_rotary_dryer_Silver Peak 0.011433538184225801
# AR
# df_rotary_dryer_Salar de Cauchari-Olaroz 0.08721864600074083
# df_rotary_dryer_Salar de Centenario 0.03483145739694503
# df_rotary_dryer_Salar de Olaroz 0.05787937033871857
# df_rotary_dryer_Fenix 0.16545817279226252
# df_rotary_dryer_Sal de los Angeles 0.04375078386821097
# CL
# df_rotary_dryer_Salar de Atacama 0.45156204882004136
# CN
# df_rotary_dryer_Chaerhan 0.11112990774418041
# df_rotary_dryer_East Taijinar 0.02321999935832184
# df_rotary_dryer_Zhabuye 0.013516075496352644
# US
# df_rotary_dryer_Silver Peak 0.011433538184225801
# AR
# df_rotary_dryer_Salar de Cauchari-Olaroz 0.08721864600074083
# df_rotary_dryer_Salar de Centenario 0.03483145739694503
# df_rotary_dryer_Salar de Olaroz 0.05787937033871857
# df_rotary_dryer_Fenix 0.16545817279226252
# df_rotary_dryer_Sal de los Angeles 0.04375078386821097
# CL
# df_rotary_dryer_Salar de Atacama 0.45156204882004136
# CN
# df_rotary_dryer_Chaerhan 0.11112990774418041
# df_rotary_dryer_East Taijinar 0.02321999935832184
# df_rotary_dryer_Zhabuye 0.013516075496352644
# US
# df_rotary_dryer_Silver Peak 0.011433538184225801
# AR
# df_rotary_dryer_Salar de Cauchari-Olaroz 0.
# DE
# df_rotary_dryer_Upper Rhine Graben 0.02030272353217585
# US
# df_rotary_dryer_Silver Peak 0.007177730541678331
# AR
# df_rotary_dryer_Salar de Cauchari-Olaroz 0.05475399907852222
# df_rotary_dryer_Salar de Centenario 0.021866443400184343
# df_rotary_dryer_Salar de Olaroz 0.03633542981353694
# df_rotary_dryer_Fenix 0.10387109931200446
# df_rotary_dryer_Tres Quebradas 0.04579190669682718
# df_rotary_dryer_Sal de los Angeles 0.027465805644177287
# df_rotary_dryer_Salar del Hombre Muerto North 0.01428221893497219
# df_rotary_dryer_Kachi 0.022888171370147738
# df_rotary_dryer_Salar de Pastos Grandes 0.021866443400184343
# df_rotary_dryer_Pozuelos 0.027465805644177287
# df_rotary_dryer_Sal de Vida 0.040696084222977484
# df_rotary_dryer_Salar de Arizaro 0.022888171370147738
# df_rotary_dryer_Salar de Tolillar 0.022888171370147738
# df_rotary_dryer_Salar del Rincon 0.022777392620716222
# BO
# df_rotary_dryer_Salar de Uyuni 0.04531857931289252
# CL
# df_rotary_dryer_Salar de Atacama 0.2834809887415374
# df_rotary_dryer_Maricunga 0.014117424101107124
# CN
# df_rotary_dryer_Chaerhan 0.06976497738991994
# df_rotary_dryer_East Taijinar 0.014577018582219695
# df_rotary_dryer_Lakkor Tso 0.04228292114406984
# df_rotary_dryer_Qinghai Yiliping 0.008655390885335072
# df_rotary_dryer_Zhabuye 0.008485102890341172
# DE
# df_rotary_dryer_Upper Rhine Graben 0.02030272353217585
# US
# df_rotary_dryer_Silver Peak 0.007177730541678331

# %%
# Export technology and process contribution and impacts intensity for projects within scenario
glo_technology_contribution_df.to_csv(RESULTS_PATH / f"impacts_glo_by_technology_{datetime.datetime.today().strftime('%d-%m-%Y')}.csv", index=0)
glo_process_contribution_df.to_csv(RESULTS_PATH / f"impacts_glo_by_source_{datetime.datetime.today().strftime('%d-%m-%Y')}.csv", index=0)

# Import results for further analysis
#process_contribution_df = pd.read_csv(RESULTS_PATH / "annual_impacts_by_source_NDC_25-02-2025.csv")

# %% [markdown]
# ## 3. Battery-level impacts

# %%
# Energy density (kWh/kg) in 2025 and 2035 based on premise
cell_energy_density = {
    "LFP": {"2025": 0.17, "2035": 0.1900},
    "NMC811": {"2025": 0.2900, "2035": 0.3100}
}

# %%
li_dbs = [d for d in bd.databases if "lithium" in d and "SSP2-NDC" in d]
lca_cell_results = []
for db in li_dbs:
    year = "2025" if "2025" in db else "2035"
    cell_actv = [ds for ds in bd.Database(db) if "battery cell production" in ds["name"]]
    lca_cells = multi_lca(cell_actv, impact_methods_obj)
    for i in lca_cells:
        cell_name = i[1].split("|")[0].split()[-1]
        cell_density = cell_energy_density[cell_name][year]
        impact_value = lca_cells[i] / cell_density
        impact_cat = [k for k,v in LCIA_METHODS.items() if v==i[0]][0]
        lca_cell_results.append((cell_name, impact_cat, db, impact_value))
lca_cell_results = pd.DataFrame(lca_cell_results, columns=["Cell chemistry", "Impact", "Li scenario", "Value"])

# %%
lca_cell_results.to_csv(RESULTS_PATH / f"impacts_by_battery_cell_{datetime.datetime.today().strftime('%d-%m-%Y')}.csv", index=0)

# %% [markdown]
# ## 4. Sensitivity analysis - reagents

# %% [markdown]
# ### 4.1 Reagents BAT, fuel switch, and CCS adoption

# %%
SA_data_file = Path(SCENARIO_DATA_PATH / "SA_reagents_lcis.xlsx")
SA_projects_ds = [ds for ds in bd.Database("lithium_optimized_S&P-Very Ambitious_remind SSP2-NDC 2035") if "df_rotary_dryer_" in ds["name"]]

scenario_label, scenario_data = get_sensitivity_analysis_data(SA_data_file)

# %%
results = {}
calculation_setup = {}
calculation_setup["inventories"] = {ds["name"] + "|" + ds["reference product"] + "|" + ds["location"]: {ds.id: 1} for ds in SA_projects_ds}
calculation_setup["methods"] = impact_methods_obj
data_objs = bd.get_multilca_data_objs(functional_units=calculation_setup["inventories"], 
                                        method_config=calculation_setup["methods"])

for scenario_name in scenario_label:
    print(scenario_name)
    mlca= bc.MultiLCA(demands=calculation_setup["inventories"], 
                      method_config=calculation_setup["methods"],
                      data_objs=data_objs)
    mlca.lci()  # build matrices

    # Apply scenario flows to matrices
    for _, row in scenario_data.iterrows():
        if row['input id'] is None or row['output id'] is None:
            continue
        amount = row[scenario_name]
        if row['from_type'] == "technosphere":
            row_idx = mlca.dicts.activity[row['input id']]
            col_idx = mlca.dicts.activity[row['output id']]
            mlca.technosphere_matrix[row_idx, col_idx] = amount * np.sign(mlca.technosphere_matrix[row_idx, col_idx])

    # Redo LCI for updated matrices
    mlca.lci()
    mlca.lcia()
    results[scenario_name] = mlca.scores
# Out:
# 2035_BAT_Fuel mix_15CCS
# 2035_BAT_Biomass_15CCS
# 2035_BAT_NG_15CCS
# 2035_BAT_Fuel mix_0CCS
# 2035_BAT_Biomass_0CCS
# 2035_BAT_NG_0CCS
# 2035_BAT_Fuel mix_100CCS
# 2035_BAT_Biomass_100CCS
# 2035_BAT_NG_100CCS
# 2035_BAT Worst_Fuel mix_15CCS
# 2035_BAT Worst_Biomass_15CCS
# 2035_BAT Worst_NG_15CCS
# 2035_BAT Worst_Fuel mix_0CCS
# 2035_BAT Worst_Biomass_0CCS
# 2035_BAT Worst_NG_0CCS
# 2035_BAT Worst_Fuel mix_100CCS
# 2035_BAT Worst_Biomass_100CCS
# 2035_BAT Worst_NG_100CCS

# %%
SA_results = []
for sa_sc in results:
    for proj in results[sa_sc]:
        impact_value = results[sa_sc][proj]
        impact_cat = [k for k,v in LCIA_METHODS.items() if v==proj[0]][0]
        proj_ds = proj[1].split("|")[0]
        proj_name = map_lithium_projects_to_lci[map_lithium_projects_to_lci["LCI dataset"] == proj_ds]["Project name"].values[0]
        SA_results.append((proj_name, impact_cat, sa_sc, impact_value))

SA_results = pd.DataFrame(SA_results, columns=["Project name", "Impact", "SA scenario", "Total"])

# %%
SA_results.to_csv(RESULTS_PATH / f"SA_reagents_{datetime.datetime.today().strftime('%d-%m-%Y')}.csv", index=0)

# %% [markdown]
# ## 5. Calculate impacts of reagents and electricity mixes

# %%
reagent_plci = []
for db in BACKGROUND_DB:
    for ds in bd.Database(db):
        if "soda ash production" in ds["name"] or "quicklime production, PFRK" in ds["name"]:
            for ex in ds.exchanges():
                reagent_plci.append((db, ds["name"], ex["name"], ex["amount"]))
reagent_plci = pd.DataFrame(reagent_plci, columns=["Database", "Activity", "Exchange name", "Echange amount"])

# %%
back_ds = [
    ("market for electricity, medium voltage, IEA", "electricity, medium voltage", "AR"),
    ("market for electricity, medium voltage, IEA", "electricity, medium voltage", "CL"),
    ("market group for electricity, medium voltage", "electricity, medium voltage", "CN"),

    ("market for quicklime, milled, packed (prospective)", "quicklime, milled, packed", "GLO"),
    ("quicklime production, PFRK, milled, loose", "quicklime, milled, packed", "GLO"),
    ("quicklime production, PFRK with carbon capture and storage, milled, loose", "quicklime, milled, packed", "GLO"),

    ("market for soda ash, light (prospective)", "soda ash, light", "GLO"),
    ("soda ash production, Solvay process", "soda ash, light", "GLO"),
    ("soda ash production, Solvay process with carbon capture and storage", "soda ash, light", "GLO"),
    ("soda ash production, trona process", "soda ash, light", "GLO"),
    ("soda production, solvay process", "soda ash, light", "RoW"),

    ("market for sodium hydroxide, without water, in 50% solution state (prospective)", "sodium hydroxide, without water, in 50% solution state", "GLO"),
    ("market for hydrochloric acid, without water, in 30% solution state", "hydrochloric acid, without water, in 30% solution state", "RoW"),
]

elec_reag_impacts = []
for db in BACKGROUND_DB:
    db_ds_list = [ds for ds in bd.Database(db) if (ds["name"], ds["reference product"], ds["location"]) in back_ds]
    # Define calculation setup
    calculation_setup = {}
    calculation_setup["inventories"] = {ds["name"] + ", " + ds["location"]: {ds.id: 1} for ds in db_ds_list}
    calculation_setup["methods"] = impact_methods_obj
    data_objs_back = bd.get_multilca_data_objs(functional_units=calculation_setup["inventories"], method_config=calculation_setup["methods"])
    mlca_back = bc.MultiLCA(demands=calculation_setup["inventories"], method_config=calculation_setup["methods"], data_objs=data_objs_back)
    mlca_back.lci()
    mlca_back.lcia()
    for i in mlca_back.scores:
        impact_value = mlca_back.scores[i]
        impact_cat = [k for k,v in LCIA_METHODS.items() if v==i[0]][0]
        elec_reag_impacts.append((db, i[1], impact_cat, impact_value))

elec_reag_impacts_df = pd.DataFrame(elec_reag_impacts, columns=["Database", "Activity", "Impact", "Value"])
elec_reag_impacts_df = elec_reag_impacts_df.pivot_table(index=['Activity', 'Impact'], columns='Database', values='Value')

# %%
elec_reag_impacts_df
# Out:
# Database                                                           ei_cutoff_3.10_remind_SSP2-NDC_2025_STEPS 2025-11-14  \
# Activity                                           Impact
# market for electricity, medium voltage, IEA, AR    Climate change                                           0.319503
#                                                    Water scarcity                                           0.432778
# market for electricity, medium voltage, IEA, CL    Climate change                                           0.256076
#                                                    Water scarcity                                           0.036778
# market for hydrochloric acid, without water, in... Climate change                                           0.817376
#                                                    Water scarcity                                           0.499160
# market for quicklime, milled, packed (prospecti... Climate change                                           1.217217
#                                                    Water scarcity                                           0.030372
# market for soda ash, light (prospective), GLO      Climate change                                           1.216437
#                                                    Water scarcity                                           0.290471
# market for sodium hydroxide, without water, in ... Climate change                                           1.142278
